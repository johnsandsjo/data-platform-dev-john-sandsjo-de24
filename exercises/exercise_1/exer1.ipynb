# %% [markdown]
# ## 1. Working with grades data

# %%
import pandas as pd

df_dict = {}
for sheet in ["Tabell 1A", "Tabell 1B"]:
    df_dict[sheet] = pd.read_excel("data/betyg_o_prov_riksnivå.xlsx", sheet_name=sheet, skiprows=7)
df_dict["Tabell 1B"]
# Out:
#                                            Unnamed: 0  Totalt  Flickor  \
# 0                                             2018/19   221.7    234.3
# 1                                             2019/20   222.9    235.7
# 2                                             2020/21   223.9    235.4
# 3                                             2021/22   221.2    231.6
# 4                                             2022/23   220.6    229.7
# 5                                               därav     NaN      NaN
# 6                                              Kommun   216.1    225.6
# 7                                             Enskild   237.9    245.0
# 8                                               därav     NaN      NaN
# 9                                   Allmän inriktning   238.5    245.8
# 10                                      Konfessionell   225.6    230.5
# 11                                            Waldorf   236.3    239.0
# ...

# %%
#a) Draw a line chart for proportion of students that are missing approved grade for one or more subjects for the years 18-23.
import seaborn as sns
import matplotlib.pyplot as plt
years =  df_dict["Tabell 1B"]["Unnamed: 0"].head(5)
percent_failed= df_dict["Tabell 1B"]["Totalt.2"].head(5)

new_dict = {years[i] : percent_failed[i] for i in range(len(percent_failed))}
df = pd.DataFrame(index = new_dict.keys(), data= new_dict.values(), columns= ['percent_failed'])
sns.lineplot(df)
# Out:
# <Axes: >

# %%
new_df_dropped = df_dict["Tabell 1B"].drop(columns= ["Totalt", "Flickor", "Totalt.1", "Pojkar", "Flickor.1", "Pojkar.1", "Flickor.2", "Pojkar.2"])
new_df_dropped
# Out:
#                                            Unnamed: 0  Totalt.2
# 0                                             2018/19      24.5
# 1                                             2019/20      23.9
# 2                                             2020/21      23.9
# 3                                             2021/22      25.9
# 4                                             2022/23      26.8
# 5                                               därav       NaN
# 6                                              Kommun      28.9
# 7                                             Enskild      18.7
# 8                                               därav       NaN
# 9                                   Allmän inriktning      18.0
# 10                                      Konfessionell      29.4
# 11                                            Waldorf      25.6
# 12                         Elever med svensk bakgrund      21.4
# 13                       Elever med utländsk bakgrund      40.2
# ...

# %%
new_df_dropped_renamed = new_df_dropped.rename({
    "Unnamed: 0": "Kategori", 
    "Totalt.2": "percent_failed"},
    axis=1)
new_df_dropped_renamed
# Out:
#                                              Kategori  percent_failed
# 0                                             2018/19            24.5
# 1                                             2019/20            23.9
# 2                                             2020/21            23.9
# 3                                             2021/22            25.9
# 4                                             2022/23            26.8
# 5                                               därav             NaN
# 6                                              Kommun            28.9
# 7                                             Enskild            18.7
# 8                                               därav             NaN
# 9                                   Allmän inriktning            18.0
# 10                                      Konfessionell            29.4
# 11                                            Waldorf            25.6
# ...

# %%
table_to_query = new_df_dropped_renamed
query = """
SELECT 
    Kategori,
    percent_failed
FROM
    table_to_query
WHERE Kategori IN ('Förgymnasial utbildning', 'Gymnasial utbildning', 'Eftergymnasial utbildning')
"""
print(query)
# Out:
# SELECT
#     Kategori,
#     percent_failed
# FROM
#     table_to_query
# WHERE Kategori IN ('Förgymnasial utbildning', 'Gymnasial utbildning', 'Eftergymnasial utbildning')

# %%
import duckdb

duckdb.query(query)
# Out:
# ┌───────────────────────────┬────────────────┐
# │         Kategori          │ percent_failed │
# │          varchar          │     double     │
# ├───────────────────────────┼────────────────┤
# │ Förgymnasial utbildning   │           63.5 │
# │ Gymnasial utbildning      │           37.4 │
# │ Eftergymnasial utbildning │           16.8 │
# └───────────────────────────┴────────────────┘

# %%
import pandas as pd
df_os = pd.read_csv("data/athlete_events.csv")
df_os
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import duckdb
duckdb.query("SELECT * FROM df_os").df()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df_os.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
#d) Find out the 10 oldest atheletes, their age and the sport
duckdb.query("""
             SELECT Name, Age, Sport FROM df_os ORDER BY AGE DESC LIMIT 10
             """).df()
# Out:
#                          Name   Age             Sport  Year
# 0      John Quincy Adams Ward  97.0  Art Competitions  1928
# 1               Winslow Homer  96.0  Art Competitions  1932
# 2  Thomas Cowperthwait Eakins  88.0  Art Competitions  1932
# 3  Thomas Cowperthwait Eakins  88.0  Art Competitions  1932
# 4  Thomas Cowperthwait Eakins  88.0  Art Competitions  1932
# 5       George Denholm Armour  84.0  Art Competitions  1948
# 6                Louis Tauzin  81.0  Art Competitions  1924
# 7        Robert Tait McKenzie  81.0  Art Competitions  1948
# 8              Max Liebermann  80.0  Art Competitions  1928
# 9              Max Liebermann  80.0  Art Competitions  1928

# %%
#d) Find out the 10 oldest atheletes, their age and the sport
duckdb.query("""
             SELECT Name, Age, Sport, Year FROM df_os ORDER BY AGE LIMIT 10
             """).df()
# Out:
#                                               Name   Age           Sport  Year
# 0                               Dimitrios Loundras  10.0      Gymnastics  1896
# 1  Megan Olwen Devenish Taylor (-Mandeville-Ellis)  11.0  Figure Skating  1932
# 2                                     Liana Vicens  11.0        Swimming  1968
# 3                                     Liana Vicens  11.0        Swimming  1968
# 4                                     Liana Vicens  11.0        Swimming  1968
# 5                                     Liana Vicens  11.0        Swimming  1968
# 6                                     Etsuko Inada  11.0  Figure Skating  1936
# 7                                       Liu Luyang  11.0  Figure Skating  1988
# 8                                Marcelle Matthews  11.0  Figure Skating  1960
# 9                       Magdalena Cecilia Colledge  11.0  Figure Skating  1932

# %%
#e) Find out the five sports with highest median age
duckdb.query("""
             SELECT Sport, MEDIAN(Age) as median_age FROM df_os GROUP BY Sport ORDER BY median_age DESC LIMIT 5
             """).df()
# Out:
#               Sport  median_age
# 0             Roque        59.0
# 1  Art Competitions        45.0
# 2          Alpinism        38.0
# 3              Polo        35.0
# 4     Equestrianism        33.0

# %%
#f) Find out the five sports with lowest median age
duckdb.query("""
             SELECT Sport, MEDIAN(Age) as median_age FROM df_os GROUP BY Sport ORDER BY median_age LIMIT 5
             """).df()
# Out:
#                  Sport  median_age
# 0  Rhythmic Gymnastics        18.0
# 1             Swimming        20.0
# 2       Figure Skating        22.0
# 3           Gymnastics        22.0
# 4               Diving        22.0

# %%
#f) Find out top 10 countries after number of gold medals
duckdb.query("""
             SELECT NOC, count(Medal) as Num_of_golds FROM df_os WHERE Medal = 'Gold' group by NOC ORDER BY Num_of_golds DESC LIMIT 10
             """).df()
# Out:
#    NOC  Num_of_golds
# 0  USA          2638
# 1  URS          1082
# 2  GER           745
# 3  GBR           678
# 4  ITA           575
# 5  FRA           501
# 6  SWE           479
# 7  CAN           463
# 8  HUN           432
# 9  GDR           397

# %%
#g) Find out top 10 countries after number of medals
duckdb.query("""
             SELECT NOC, count(Medal) as Num_of_golds FROM df_os group by NOC ORDER BY Num_of_golds DESC LIMIT 10
             """).df()
# Out:
#    NOC  Num_of_golds
# 0  USA          5637
# 1  URS          2503
# 2  GER          2165
# 3  GBR          2068
# 4  FRA          1777
# 5  ITA          1637
# 6  SWE          1536
# 7  CAN          1352
# 8  AUS          1320
# 9  RUS          1165

# %%
df_os.groupby(df_os["Year"])
# Out:
# Year  ID      Name                             Sex  Age   Height  Weight  Team           NOC  Games        Season  City            Sport       Event                                       Medal
# 1896  16616   Thomas Edmund "Tom" Burke        M    21.0  183.0   66.0    United States  USA  1896 Summer  Summer  Athina          Athletics   Athletics Men's 100 metres                  Gold      1
#                                                                                                                                                Athletics Men's 400 metres                  Gold      1
#       22700   James Brendan Bennet Connolly    M    27.0  175.0   72.0    United States  USA  1896 Summer  Summer  Athina          Athletics   Athletics Men's High Jump                   Silver    1
#                                                                                                                                                Athletics Men's Long Jump                   Bronze    1
# ...

# %%
#with sns
import matplotlib.pyplot as plt
import seaborn as sns

# h) Plot a time series line chart of number of female and male atheletes in same graph.
new_df = duckdb.query(
    """
                      SELECT 
                      Year, Sex, count(Sex) as count 
                      FROM 
                      df_os 
                      group by Year, Sex 
                      ORDER BY Year ASC
                      """
).df()
new_df
sns.lineplot(new_df, x=new_df["Year"], y=new_df["count"], hue="Sex")
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
# with matplotlib
import matplotlib.pyplot as plt

# h) Plot a time series line chart of number of female and male atheletes in same graph.
new_df = duckdb.query(
    """
                      SELECT 
                      Year, Sex, count(Sex) as count 
                      FROM 
                      df_os 
                      group by Year, Sex 
                      ORDER BY Year ASC
                      """
).df()
male = new_df[new_df['Sex'] == "M"]
female = new_df[new_df['Sex'] == "F"]
line1 = plt.plot(male["Year"], male["count"], label="male")
line2 = plt.plot(female["Year"], female["count"], label="female")
plt.legend()
plt.xlabel("Year")
plt.ylabel("count")
plt.title("Men and Women participants over the years")
# Out:
# Text(0.5, 1.0, 'Men and Women participants over the years')

# %%
#with oop approach
fig, ax = plt.subplots(1)
male = new_df[new_df['Sex'] == "M"]
female = new_df[new_df['Sex'] == "F"]
ax.plot(male["Year"], male["count"], label="Male")
ax.plot(female["Year"], female["count"], label="Female")
ax.legend()
ax.set(title="Men and Women participants over the years", xlabel="age", ylabel="count")
# Out:
# [Text(0.5, 1.0, 'Men and Women participants over the years'),
#  Text(0.5, 0, 'age'),
#  Text(0, 0.5, 'count')]
